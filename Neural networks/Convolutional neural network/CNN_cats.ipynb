# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from google.colab import files
from io import BytesIO
from PIL import Image

# %%
model = keras.applications.VGG16()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 4s 0us/step
# 553476096/553467096 [==============================] - 4s 0us/step

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e04d4376-b171-4b9c-b3ec-8849881f9337" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e04d4376-b171-4b9c-b3ec-8849881f9337">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Vishnu.jpeg to Vishnu (1).jpeg

# %%
img = Image.open(BytesIO(uploaded['Vishnu.jpeg']))
plt.imshow( img )

# %% [markdown]
# # Приводим к входному формату VGG-сети

# %%
img = np.array(img)
x = keras.applications.vgg16.preprocess_input(img)
print(x.shape)
x = np.expand_dims(x, axis=0)
# Out:
# (244, 244, 3)

# %% [markdown]
# # Прогоняем через сеть

# %%
res = model.predict(x)
print(np.argmax(res))
# Out:
# 283
